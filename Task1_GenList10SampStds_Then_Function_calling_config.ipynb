# %% [markdown]
# <a href="https://colab.research.google.com/github/CrystleYS/Q2-Lecture-4/blob/main/Task1_GenList10SampStds_Then_Function_calling_config.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##### Copyright 2024 Google LLC.
#
# ## 1- TASK IS TO GENERATE LIST OF 10 SAMPLE STUDENTS LIST WITH RollNumber, Name, Father, Address.
#
# ## 2- USE FUNCTION CALLING TOOL SYSTEM TO GET Desire Data of Student roll Number.

# %%
# prompt: Generate list of dictionary with 10 samples and keys would be Roll Number, Name, Father, Address.

import random

def generate_student_data(num_students=10):
  students = []
  for i in range(num_students):
    student = {
        'Roll Number': i + 1,
        'Name': f'Student {i+1}',
        'Father': f'Father {i+1}',
        'Address': f'Address {i+1}'
    }
    students.append(student)
  return students

student_list = generate_student_data()
student_list
# Out:
# [{'Roll Number': 1,
#   'Name': 'Student 1',
#   'Father': 'Father 1',
#   'Address': 'Address 1'},
#  {'Roll Number': 2,
#   'Name': 'Student 2',
#   'Father': 'Father 2',
#   'Address': 'Address 2'},
#  {'Roll Number': 3,
#   'Name': 'Student 3',
#   'Father': 'Father 3',
#   'Address': 'Address 3'},
#  {'Roll Number': 4,
#   'Name': 'Student 4',
#   'Father': 'Father 4',
#   'Address': 'Address 4'},
#  {'Roll Number': 5,
#   'Name': 'Student 5',
#   'Father': 'Father 5',
#   'Address': 'Address 5'},
#  {'Roll Number': 6,
#   'Name': 'Student 6',
#   'Father': 'Father 6',
#   'Address': 'Address 6'},
#  {'Roll Number': 7,
#   'Name': 'Student 7',
#   'Father': 'Father 7',
#   'Address': 'Address 7'},
#  {'Roll Number': 8,
#   'Name': 'Student 8',
#   'Father': 'Father 8',
#   'Address': 'Address 8'},
#  {'Roll Number': 9,
#   'Name': 'Student 9',
#   'Father': 'Father 9',
#   'Address': 'Address 9'},
#  {'Roll Number': 10,
#   'Name': 'Student 10',
#   'Father': 'Father 10',
#   'Address': 'Address 10'}]

# %%
# prompt: use Function calling tool  system to enter student roll number 5  and get complete information

import random
# ##### Copyright 2024 Google LLC.
#
# ## 1- TASK IS TO GENERATE LIST OF 10 SAMPLE STUDENTS LIST WITH RollNumber, Name, Father, Address.
#
# ## 2- USE FUNCTION CALLING TOOL SYSTEM TO GET Desire Data of Student roll Number.
#
#
#


def generate_student_data(num_students=10):
  students = []
  for i in range(num_students):
    student = {
        'Roll Number': i + 1,
        'Name': f'Student {i+1}',
        'Father': f'Father {i+1}',
        'Address': f'Address {i+1}'
    }
    students.append(student)
  return students

def get_student_info(roll_number, student_list):
    for student in student_list:
        if student['Roll Number'] == roll_number:
            return student
    return "Student not found"

student_list = generate_student_data()

# Example using function calling
roll_number_to_find = 5
student_info = get_student_info(roll_number_to_find, student_list)
student_info
# Out:
# {'Roll Number': 5,
#  'Name': 'Student 5',
#  'Father': 'Father 5',
#  'Address': 'Address 5'}
